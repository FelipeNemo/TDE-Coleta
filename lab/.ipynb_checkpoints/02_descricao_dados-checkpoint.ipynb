# %% [markdown]
# # 📘 descricao_dados
# ### **Objetivo:**
# - Descrever campos, tipos, exemplos e significado dos dados coletados.

# %%
import pandas as pd

# Ler JSONs processados
df_dep = pd.read_json("../data/processed/deputados.json")
df_evt = pd.read_json("../data/processed/eventos.json")

print("📘 Estrutura — Deputados:")
df_dep.info()
print("\n📗 Estrutura — Eventos:")
df_evt.info()
# Out:
# 📘 Estrutura — Deputados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             100 non-null    int64
#  1   uri            100 non-null    object
#  2   nome           100 non-null    object
#  3   siglaPartido   100 non-null    object
#  4   uriPartido     100 non-null    object
#  5   siglaUf        100 non-null    object
#  6   idLegislatura  100 non-null    int64
#  7   urlFoto        100 non-null    object
#  8   email          100 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB
#
# 📗 Estrutura — Eventos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9213 entries, 0 to 9212
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              9213 non-null   int64
# ...

# %%
# Montar tabela descritiva de campos e tipos
descricao = pd.concat([
    pd.DataFrame({
        "Dataset": "deputados",
        "Campo": df_dep.columns,
        "Tipo de Dado": df_dep.dtypes.astype(str)
    }),
    pd.DataFrame({
        "Dataset": "eventos",
        "Campo": df_evt.columns,
        "Tipo de Dado": df_evt.dtypes.astype(str)
    })
])

# Salvar e mostrar amostra
descricao.to_json("../data/processed/descritivo_campos.json", orient="records", indent=2, force_ascii=False)
print("✅ Descritivo salvo em: data/processed/descritivo_campos.json")
descricao.head(10)
# Out:
# ✅ Descritivo salvo em: data/processed/descritivo_campos.json
#                  Dataset          Campo Tipo de Dado
# id             deputados             id        int64
# uri            deputados            uri       object
# nome           deputados           nome       object
# siglaPartido   deputados   siglaPartido       object
# uriPartido     deputados     uriPartido       object
# siglaUf        deputados        siglaUf       object
# idLegislatura  deputados  idLegislatura        int64
# urlFoto        deputados        urlFoto       object
# email          deputados          email       object
# id               eventos             id        int64
